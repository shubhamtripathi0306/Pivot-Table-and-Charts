# %% [markdown]
# 1. What is the purpose of a PivotTable in Excel?
#
#   A PivotTable in Excel is used to summarize, analyze, and explore
# large sets of data quickly and interactively—without changing the original data.
# A PivotTable helps you turn raw data into meaningful insights quickly and flexibly.
# and the purpose is to quickly summarize and analyze large amounts of data in Excel
#
# 4. Explain the difference between Sorting and Filtering with an example from this dataset.
#
# * **Sorting** arranges data in a specific order (ascending or descending) without removing any data.
#
# * **Filtering** displays only the data that meets certain criteria and hides the rest.
#
#
# so in the given sheet if i want to short the quantity of pdoduct from lowest to highest i can apply the short function to see which product has lowest and highest numbers
#
# and for the filtering i can simply apply filter and directly see by selecting the particular field value which i want to show
#
#
#   7. Why are Dashboards important for decision-making in business analysis?
#
#   Dashboards are important for decision-making in business analysis because they **present key data and performance indicators in a clear, visual, and real-time format**, making information easy to understand at a glance. They help decision-makers **identify trends, track performance, spot problems quickly, and make informed decisions faster** without analyzing raw data.
